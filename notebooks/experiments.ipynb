# %% [markdown]
# # Motion Estimation Experiments
#
# This notebook is a starting point for comparing Full Search and Diamond Search motion estimation algorithms.

# %%
from src.utils.config import Config

print("This notebook is a scaffold for experiments.")
